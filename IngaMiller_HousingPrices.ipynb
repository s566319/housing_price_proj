# %% [markdown]
# # Final Project: Housing Price Projection

# %% [markdown]
# Author: [Inga Miller](https://github.com/s566319) Repository: https://github.com/s566319/housing_price_proj

# %% [markdown]
# Date- 11/2/2024

# %% [markdown]
# ## Section 1-Load

# %%
# Section 1-Load: Get the file, store it in your repo, and load it into a DataFrame. 

import pandas as pd
Housing = pd.read_csv ('Housing.csv')

# %% [markdown]
# ## Section 2-View

# %%
# Section 2-View: Display the first 7 rows and the last 7 rows.

Housing.head(7)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000  2.31e+05         2       1.00         1180
# 1  6414100192  20141209T000000  5.38e+05         3       2.25         2570
# 2  5631500400  20150225T000000  1.80e+05         2       1.00          770
# 3  2487200875  20141209T000000  6.04e+05         4       3.00         1960
# 4  1954400510  20150218T000000  5.10e+05         3       2.00         1680
# 5  7237550310  20140512T000000  1.22e+06         4       4.50         5420
# 6  1321400060  20140627T000000  2.58e+05         3       2.25         1715
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# 5    101930     1.0           0     0  ...     11        3890           1530
# 6      6819     2.0           0     0  ...      7        1715              0
#
#    yr_built  yr_renovated  zipcode    lat    long  sqft_living15  sqft_lot15
# 0      1955             0    98178  47.51 -122.26           1340        5650
# 1      1951          1991    98125  47.72 -122.32           1690        7639
# 2      1933             0    98028  47.74 -122.23           2720        8062
# 3      1965             0    98136  47.52 -122.39           1360        5000
# 4      1987             0    98074  47.62 -122.05           1800        7503
# 5      2001             0    98053  47.66 -122.00           4760      101930
# 6      1995             0    98003  47.31 -122.33           2238        6819
#
# [7 rows x 21 columns]

# %%
Housing.tail(7)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21606  7936000429  20150326T000000  1.01e+06         4       3.50
# 21607  2997800021  20150219T000000  4.75e+05         3       2.50
# 21608   263000018  20140521T000000  3.60e+05         3       2.50
# 21609  6600060120  20150223T000000  4.00e+05         4       2.50
# 21610  1523300141  20140623T000000  4.02e+05         2       0.75
# 21611   291310100  20150116T000000  4.00e+05         3       2.50
# 21612  1523300157  20141015T000000  3.25e+05         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21606         3510      7200     2.0           0     0  ...      9
# 21607         1310      1294     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode    lat  \
# 21606        2600            910      2009             0    98136  47.55
# 21607        1180            130      2008             0    98116  47.58
# 21608        1530              0      2009             0    98103  47.70
# 21609        2310              0      2014             0    98146  47.51
# 21610        1020              0      2009             0    98144  47.59
# 21611        1600              0      2004             0    98027  47.53
# 21612        1020              0      2008             0    98144  47.59
#
#          long  sqft_living15  sqft_lot15
# 21606 -122.40           2050        6200
# 21607 -122.41           1330        1265
# 21608 -122.35           1530        1509
# 21609 -122.36           1830        7200
# 21610 -122.30           1020        2007
# 21611 -122.07           1410        1287
# 21612 -122.30           1020        1357
#
# [7 rows x 21 columns]

# %% [markdown]
# ## Section 3-Describe

# %%
# Section 3-Describe: Use the DataFrame describe() function to calculate basic descriptive statistics for all numeric columns. 

pd.set_option("display.precision", 2)
Housing.describe()
# Out:
#              id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# count  2.16e+04  2.16e+04  21613.00   21613.00     21613.00  2.16e+04
# mean   4.58e+09  5.40e+05      3.37       2.11      2079.90  1.51e+04
# std    2.88e+09  3.67e+05      0.93       0.77       918.44  4.14e+04
# min    1.00e+06  7.50e+04      0.00       0.00       290.00  5.20e+02
# 25%    2.12e+09  3.22e+05      3.00       1.75      1427.00  5.04e+03
# 50%    3.90e+09  4.50e+05      3.00       2.25      1910.00  7.62e+03
# 75%    7.31e+09  6.45e+05      4.00       2.50      2550.00  1.07e+04
# max    9.90e+09  7.70e+06     33.00       8.00     13540.00  1.65e+06
#
#          floors  waterfront      view  condition     grade  sqft_above  \
# count  21613.00    2.16e+04  21613.00   21613.00  21613.00    21613.00
# mean       1.49    7.54e-03      0.23       3.41      7.66     1788.39
# std        0.54    8.65e-02      0.77       0.65      1.18      828.09
# min        1.00    0.00e+00      0.00       1.00      1.00      290.00
# 25%        1.00    0.00e+00      0.00       3.00      7.00     1190.00
# 50%        1.50    0.00e+00      0.00       3.00      7.00     1560.00
# 75%        2.00    0.00e+00      0.00       4.00      8.00     2210.00
# max        3.50    1.00e+00      4.00       5.00     13.00     9410.00
#
#        sqft_basement  yr_built  yr_renovated   zipcode       lat      long  \
# count       21613.00  21613.00      21613.00  21613.00  21613.00  21613.00
# mean          291.51   1971.01         84.40  98077.94     47.56   -122.21
# std           442.58     29.37        401.68     53.51      0.14      0.14
# min             0.00   1900.00          0.00  98001.00     47.16   -122.52
# 25%             0.00   1951.00          0.00  98033.00     47.47   -122.33
# 50%             0.00   1975.00          0.00  98065.00     47.57   -122.23
# 75%           560.00   1997.00          0.00  98118.00     47.68   -122.12
# max          4820.00   2015.00       2015.00  98199.00     47.78   -121.31
#
#        sqft_living15  sqft_lot15
# count       21613.00    21613.00
# mean         1986.55    12768.46
# std           685.39    27304.18
# min           399.00      651.00
# 25%          1490.00     5100.00
# 50%          1840.00     7620.00
# 75%          2360.00    10083.00
# max          6210.00   871200.00

# %% [markdown]
# ## Section 4-Series

# %%
# Section 4-Series: Use the Series method describe() to calculate the descriptive stats for all category/text columns.

Housing.describe(include=[object])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# ## Section 5-Unique

# %%
# Section 5-Unique: Use the Series method unique() to get unique category values. 

Housing["zipcode"].unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039], dtype=int64)

# %%
Housing["bedrooms"].unique()
# Out:
# array([ 2,  3,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
Housing["bathrooms"].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 0.  , 1.25, 5.25, 6.  , 0.5 ,
#        5.5 , 6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %% [markdown]
# ## Section 6-Histograms

# %%
# Section 6-Histograms: Use the DataFrame's hist() function to create a histogram for each numerical column.

# %matplotlib inline
histogram = Housing.hist()
