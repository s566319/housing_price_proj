# %% [markdown]
# # Final Project: Housing Price Projection

# %% [markdown]
# Author: [Inga Miller](https://github.com/s566319) Repository: https://github.com/s566319/housing_price_proj

# %% [markdown]
# Date- 11/2/2024

# %% [markdown]
# ## Section 1-Data

# %% [markdown]
# ### Data Collection

# %%
# Section 1-Load: Get the file, store it in your repo, and load it into a DataFrame. 

import pandas as pd
import numpy as np 
import plotly.express as px 
import matplotlib.pyplot as plt 
import seaborn as sns
Housing = pd.read_csv ('HousingCleaned.csv')

# %% [markdown]
# ### Data View

# %%
# Section 2-View: Display the first 7 rows and the last 7 rows.

Housing.head(7)
# Out:
#            id      date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7229300521  20141013   231300         2        1.0         1180      5650
# 1  6414100192  20141209   538000         3        2.0         2570      7242
# 2  5631500400  20150225   180000         2        1.0          770     10000
# 3  2487200875  20141209   604000         4        3.0         1960      5000
# 4  1954400510  20150218   510000         3        2.0         1680      8080
# 5  7237550310  20140512  1230000         4        4.5         5420    101930
# 6  1321400060  20140627   257500         3        2.0         1715      6819
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# ...

# %%
Housing.tail(7)
# Out:
#                id      date    price  bedrooms  bathrooms  sqft_living  \
# 21580  7936000429  20150326  1010000         4        3.5         3510
# 21581  2997800021  20150219   475000         3        2.5         1310
# 21582   263000018  20140521   360000         3        2.5         1530
# 21583  6600060120  20150223   400000         4        2.5         2310
# 21584  1523300141  20140623   402101         2        1.0         1020
# 21585   291310100  20150116   400000         3        2.5         1600
# 21586  1523300157  20141015   325000         2        1.0         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21580      7200     2.0           0     0  ...      9        2600
# 21581      1294     2.0           0     0  ...      8        1180
# 21582      1131     3.0           0     0  ...      8        1530
# 21583      5813     2.0           0     0  ...      8        2310
# 21584      1350     2.0           0     0  ...      7        1020
# ...

# %% [markdown]
# ### Data Description

# %%
# Section 3-Describe: Use the DataFrame describe() function to calculate basic descriptive statistics for all numeric columns. 

pd.set_option("display.precision", 2)
Housing.describe()
# Out:
#              id      date     price  bedrooms  bathrooms  sqft_living  \
# count  2.16e+04  2.16e+04  2.16e+04  21587.00   21587.00     21587.00
# mean   4.58e+09  2.01e+07  5.40e+05      3.37       2.14      2080.14
# std    2.88e+09  4.44e+03  3.67e+05      0.90       0.76       917.84
# min    1.00e+06  2.01e+07  7.80e+04      1.00       1.00       370.00
# 25%    2.12e+09  2.01e+07  3.22e+05      3.00       2.00      1430.00
# 50%    3.90e+09  2.01e+07  4.50e+05      3.00       2.00      1910.00
# 75%    7.31e+09  2.02e+07  6.45e+05      4.00       2.50      2550.00
# max    9.90e+09  2.02e+07  7.70e+06      9.00       8.00     13540.00
#
#        sqft_lot    floors  waterfront      view  ...     grade  sqft_above  \
# count  2.16e+04  21587.00    2.16e+04  21587.00  ...  21587.00    21587.00
# mean   1.51e+04      1.49    7.55e-03      0.23  ...      7.66     1788.55
# std    4.14e+04      0.54    8.66e-02      0.77  ...      1.17      827.59
# ...

# %% [markdown]
# ### Additional Data Description

# %%
# Section 3-Describe: Use the DataFrame describe() function to calculate basic descriptive statistics for all numeric columns. 


print ("Rows     : " ,Housing.shape[0])
print ("Columns  : " ,Housing.shape[1])
print ("\nFeatures : \n" ,Housing.columns.tolist())
print ("\nMissing values :  ", Housing.isnull().sum().values.sum())
print ("\nUnique values :  \n",Housing.nunique())
# Out:
# Rows     :  21587
# Columns  :  21
#
# Features :
#  ['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
#
# Missing values :   0
#
# Unique values :
#  id               21410
# date               372
# price             3622
# bedrooms             9
# bathrooms           14
# sqft_living       1034
# sqft_lot          9774
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      776
# sqft_lot15        8681
# dtype: int64

# %% [markdown]
# ### Data Descirptive Stats

# %%
Housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21587 entries, 0 to 21586
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21587 non-null  int64
#  1   date           21587 non-null  int64
#  2   price          21587 non-null  int64
#  3   bedrooms       21587 non-null  int64
#  4   bathrooms      21587 non-null  float64
#  5   sqft_living    21587 non-null  int64
#  6   sqft_lot       21587 non-null  int64
#  7   floors         21587 non-null  float64
#  8   waterfront     21587 non-null  int64
#  9   view           21587 non-null  int64
#  10  condition      21587 non-null  int64
#  11  grade          21587 non-null  int64
#  12  sqft_above     21587 non-null  int64
#  13  sqft_basement  21587 non-null  int64
#  14  yr_built       21587 non-null  int64
#  15  yr_renovated   21587 non-null  int64
#  16  zipcode        21587 non-null  int64
# ...

# %% [markdown]
# ## Section 2- Data Cleaning

# %%
Housing['date'] = pd.to_datetime(Housing['date'])

# %% [markdown]
# ## Section 3-Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Histograms

# %%
# Section 6-Histograms: Use the DataFrame's hist() function to create a histogram for each numerical column.

# %matplotlib inline
histogram = Housing.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)

# %% [markdown]
# ### Distributions:

# %%
import pandas as pd
print(Housing.head(n=10))
print(Housing.describe())
Housing.corr()
# Out:
#            id                          date    price  bedrooms  bathrooms  \
# 0  7229300521 1970-01-01 00:00:00.020141013   231300         2        1.0
# 1  6414100192 1970-01-01 00:00:00.020141209   538000         3        2.0
# 2  5631500400 1970-01-01 00:00:00.020150225   180000         2        1.0
# 3  2487200875 1970-01-01 00:00:00.020141209   604000         4        3.0
# 4  1954400510 1970-01-01 00:00:00.020150218   510000         3        2.0
# 5  7237550310 1970-01-01 00:00:00.020140512  1230000         4        4.5
# 6  1321400060 1970-01-01 00:00:00.020140627   257500         3        2.0
# 7  2008000270 1970-01-01 00:00:00.020150115   291850         3        1.5
# 8  2414600126 1970-01-01 00:00:00.020150415   229500         3        1.0
# 9  3793500160 1970-01-01 00:00:00.020150312   323000         3        2.5
#
#    sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0     0  ...      7        1180
# ...

# %% [markdown]
# #### Price Distribution

# %%
px.scatter(Housing,'price')

# %% [markdown]
# #### Average Price for Bedroom Count

# %%
bedroom_price = Housing.groupby('bedrooms')['price'].mean().reset_index()
bedroom_price
# Out:
#    bedrooms     price
# 0         1  3.19e+05
# 1         2  4.01e+05
# 2         3  4.66e+05
# 3         4  6.36e+05
# 4         5  7.87e+05
# 5         6  8.26e+05
# 6         7  9.51e+05
# 7         8  1.11e+06
# 8         9  9.83e+05

# %%
px.line(bedroom_price ,x='bedrooms',y='price',title='Average Price Trend Compared to count of Bedrooms')

# %% [markdown]
# #### Count by Bedrooms in each Condition

# %%
grade_condition =pd.crosstab(Housing['bedrooms'], Housing['condition'])
grade_condition
# Out:
# condition   1   2     3     4    5
# bedrooms
# 1           4  10   122    47   12
# 2          12  51  1779   717  200
# 3           8  69  6307  2711  728
# 4           4  36  4579  1682  580
# 5           0   1  1031   418  151
# 6           1   3   158    87   23
# 7           0   0    25     9    4
# 8           0   0     8     3    2
# 9           0   0     5     0    0

# %% [markdown]
# #### Average Price for Bathroom Count

# %%
bathroom_price = Housing.groupby('bathrooms')['price'].mean().reset_index()
bathroom_price
# Out:
#     bathrooms     price
# 0         1.0  3.47e+05
# 1         1.5  4.09e+05
# 2         2.0  4.79e+05
# 3         2.5  5.54e+05
# 4         3.0  7.47e+05
# 5         3.5  9.32e+05
# 6         4.0  1.29e+06
# 7         4.5  1.33e+06
# 8         5.0  1.86e+06
# 9         5.5  2.52e+06
# 10        6.0  2.82e+06
# 11        6.5  1.71e+06
# 12        7.0  2.74e+06
# 13        8.0  5.62e+06

# %%
px.line(bathroom_price ,x='bathrooms',y='price',title='Average Price Trend Compared to count of Bathrooms')

# %% [markdown]
# #### Count by Bathrooms in each Condition

# %%
grade_condition =pd.crosstab(Housing['bathrooms'], Housing['condition'])
grade_condition
# Out:
# condition   1   2     3     4    5
# bathrooms
# 1.0        20  90  2210  1300  311
# 1.5         5  12   824   497  107
# 2.0         4  50  3802  2420  747
# 2.5         0  13  4370   784  210
# 3.0         0   5  1712   552  256
# 3.5         0   0   655    42   34
# 4.0         0   0   287    57   26
# 4.5         0   0    84    10    6
# 5.0         0   0    45     8    3
# 5.5         0   0     8     2    0
# 6.0         0   0    11     1    0
# 6.5         0   0     2     0    0
# 7.0         0   0     2     0    0
# 8.0         0   0     2     1    0

# %% [markdown]
# ### Bedrooms vs Bathrooms BarChart

# %%
px.imshow(grade_condition,
                 labels=dict(x="Condition", y="Bedrooms", color="Count"),
                 x=grade_condition.columns,
                 y=grade_condition.index,
                 color_continuous_scale='viridis',
                 title='Analytical Table between Bedrooms and Condition')

# %%
bathroom_bedroom = Housing.groupby('bathrooms')['bedrooms'].mean().reset_index().astype(int)
bathroom_bedroom

px.bar( bathroom_bedroom,x='bathrooms',y='bedrooms',title='Bedrooms vs Bathrooms')

# %% [markdown]
# #### Coorolation between Average Price and Condition

# %%
condition_price = Housing.groupby('condition')['price'].mean().reset_index()
condition_price
# Out:
#    condition      price
# 0          1  341067.24
# 1          2  328178.76
# 2          3  542206.31
# 3          4  521371.12
# 4          5  612561.61

# %%
px.bar(condition_price, x='condition', y='price',title='Average Price for Condition')

# %% [markdown]
# ## Section 5- Model Building

# %% [markdown]
# Identifying independant and dependant variables

# %%
ind_var = Housing[['bedrooms', 'bathrooms', 'condition', 'yr_built', 'zipcode']]
dep_var = Housing['price']

# %% [markdown]
# Splitting data into 80/20

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(ind_var, dep_var , test_size = 0.2, random_state = 123, stratify=None)
print("Training set shape:", x_train.shape, y_train.shape)
print("Testing set shape:", x_test.shape, y_test.shape)
# Out:
# Training set shape: (17269, 5) (17269,)
# Testing set shape: (4318, 5) (4318,)

# %% [markdown]
# ### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
import numpy as np

linear_regression = LinearRegression()
linear_regression.fit(x_train, y_train)
y_train_pred = linear_regression.predict(x_train)
y_test_pred = linear_regression.predict(x_test)
train_rmse_lr = np.sqrt(root_mean_squared_error(y_train, y_train_pred))
test_rmse_lr = np.sqrt(root_mean_squared_error(y_test, y_test_pred))
print(f"Train RMSE: {train_rmse_lr}")
print(f"Test RMSE: {test_rmse_lr}\n")
print("R squared for train is :",linear_regression.score(x_train,y_train)*100)
print("R squared for test is :", linear_regression.score(x_test,y_test)*100)
# Out:
# Train RMSE: 550.119463245084
# Test RMSE: 552.1860540217937
#
# R squared for train is : 31.974036632139924
# R squared for test is : 31.81690078354564

# %% [markdown]
# ### Plot Linear Regression Model

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.scatter(y_test, y_test_pred, alpha=0.7, color='orange', label='Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='green', linestyle='--', label='Predicted')

plt.xlabel("Actual Sold House Prices")
plt.ylabel("Predicted House Prices")
plt.title("Actual vs. Predicted House Prices using Linear Regressor Model")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=42)
rf.fit(x_train, y_train)
y_train_pred = rf.predict(x_train)
y_test_pred = rf.predict(x_test)
train_rmse_rf = np.sqrt(root_mean_squared_error(y_train, y_train_pred))
test_rmse_rf = np.sqrt(root_mean_squared_error(y_test, y_test_pred))
print(f"Train RMSE: {train_rmse_rf}")
print(f"Test RMSE: {test_rmse_rf}\n")
print("R squared for train is :",rf.score(x_train,y_train)*100)
print("R squared for test is :", rf.score(x_test,y_test)*100)
# Out:
# Train RMSE: 323.6360216233176
# Test RMSE: 471.6896612520667
#
# R squared for train is : 91.85156746766731
# R squared for test is : 63.695502395925466

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.scatter(y_test, y_test_pred, alpha=0.7, color='orange', label='Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='green', linestyle='--', label='Predicted')

plt.xlabel("Actual Sold House Prices")
plt.ylabel("Predicted House Prices")
plt.title("Actual vs. Predicted House Prices using Random Forest Regressor Model")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(random_state=42)
dt.fit(x_train, y_train)
y_train_pred = dt.predict(x_train)
y_test_pred = dt.predict(x_test)
train_rmse_dt = np.sqrt(root_mean_squared_error(y_train, y_train_pred))
test_rmse_dt = np.sqrt(root_mean_squared_error(y_test, y_test_pred))
print(f"Train RMSE: {train_rmse_dt}")
print(f"Test RMSE: {test_rmse_dt}\n")
print("R squared for train is :",dt.score(x_train,y_train)*100)
print("R squared for test is :", dt.score(x_test,y_test)*100)
# Out:
# Train RMSE: 244.95578907706138
# Test RMSE: 547.9168935176895
#
# R squared for train is : 97.32577780342531
# R squared for test is : 33.90117096178693

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.scatter(y_test, y_test_pred, alpha=0.7, color='orange', label='Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='green', linestyle='--', label='Predicted')

plt.xlabel("Actual Sold House Prices")
plt.ylabel("Predicted House Prices")
plt.title("Actual vs. Predicted House Prices using Decision Tree Regressor Model")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Results of the regression models to predict housing prices
#
# | Model | Training Features | RMSE train | R2 train | RMSE test | R2 test |
# |:---|:---|:---|:---|:---|:---|
# |Linear Regression|Bedrooms, Bathrooms, Condition, Year Built, Zipcode|550.11|31.97|552.18|31.81|
# |Random Forest Regressor|Bedrooms, Bathrooms, Condition, Year Built, Zipcode|323.62|91.85|471.69|63.69|
# |Decision Tree Regressor|Bedrooms, Bathrooms, Condition, Year Built, Zipcode|244.95|97.91|547.92|33.90|

# %% [markdown]
# ##### I will be selecting Decision Tree Regressor model to predict future house prices.  The R2 training results are high at 98%, and test results are high as well with 34%. The RMSE for this model is the lowest, indicating it fits data well, and has more precise prediction.
# #### R-squared is a measure of how much variance is explained by the model and RMSE is giving you hint on average error.
# #### Low RMSE values indicate that the model fits the data well and has more precise predictions. Conversely, higher values suggest more error and less precise predictions
# #### Since the housing prices are so high, the RMSE is extremely low (fits data well)

# %%
import numpy as np

def split_dataset(dataset, test_ratio=0.30):
  test_indices = np.random.rand(len(dataset)) < test_ratio
  return dataset[~test_indices], dataset[test_indices]

train_ds_pd, valid_ds_pd = split_dataset(Housing)
print("{} examples in training, {} examples in testing.".format(
    len(train_ds_pd), len(valid_ds_pd)))
# Out:
# 15000 examples in training, 6587 examples in testing.

# %%
Housing.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
y = Housing.price

# %%
Housing_features = ['price', 'bedrooms', 'bathrooms', 'yr_built', 'zipcode']

# %%
X = Housing[Housing_features]
X.describe()
# Out:
#           price  bedrooms  bathrooms  yr_built   zipcode
# count  2.16e+04  21587.00   21587.00  21587.00  21587.00
# mean   5.40e+05      3.37       2.14   1971.01  98077.94
# std    3.67e+05      0.90       0.76     29.37     53.51
# min    7.80e+04      1.00       1.00   1900.00  98001.00
# 25%    3.22e+05      3.00       2.00   1951.00  98033.00
# 50%    4.50e+05      3.00       2.00   1975.00  98065.00
# 75%    6.45e+05      4.00       2.50   1997.00  98118.00
# max    7.70e+06      9.00       8.00   2015.00  98199.00

# %%
X.head()
# Out:
#     price  bedrooms  bathrooms  yr_built  zipcode
# 0  231300         2        1.0      1955    98178
# 1  538000         3        2.0      1951    98125
# 2  180000         2        1.0      1933    98028
# 3  604000         4        3.0      1965    98136
# 4  510000         3        2.0      1987    98074

# %%
from sklearn.tree import DecisionTreeRegressor

# Define model. Specify a number for random_state to ensure same results each run
Housing_model = DecisionTreeRegressor(random_state=1)

# Fit model
Housing_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40240\4114156749.py in ?()
#       3 # Define model. Specify a number for random_state to ensure same results each run
#       4 Housing_model = DecisionTreeRegressor(random_state=1)
#       5
#       6 # Fit model
# ----> 7 Housing_model.fit(X_train, y_train)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
print("Making predictions for the following 5 houses:")
print(X.head())
print("The price predictions are")
print(Housing_model.predict(X.head()))
# Out:
# Making predictions for the following 5 houses:
#     price  bedrooms  bathrooms  yr_built  zipcode
# 0  231300         2        1.0      1955    98178
# 1  538000         3        2.0      1951    98125
# 2  180000         2        1.0      1933    98028
# 3  604000         4        3.0      1965    98136
# 4  510000         3        2.0      1987    98074
# The price predictions are
# [231300. 538000. 180000. 604000. 510000.]
